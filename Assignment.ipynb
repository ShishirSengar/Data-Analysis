# %% [markdown]
# <a href="https://colab.research.google.com/github/ShishirSengar/Data-Analysis/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_frame = pd.read_csv("./order.csv")

# %%
data_frame
# Out:
#     order_id customer_id           order_date    amount     status  \
# 0          1      cust_1            9/10/2025  $120.50   Completed
# 1          2      cust_2            8/22/2025        80   complete
# 2          3      cust_3            7/15/2025       200          C
# 3          4      cust_1             8/1/2025       150  Completed
# 4          5      cust_4  2025-09-01T00:00:00      $60    Returned
# 5          6      cust_2                  NaN        90  Completed
# 6          7      cust_5            8/30/2025       250  Completed
# 7          8      cust_3            9/12/2025   $75.25   Completed
# 8          9      cust_6             8/5/2025        30  completed
# 9         10      cust_1            6/20/2025       400  Completed
# 10        11      cust_7            9/14/2025        15  Completed
# 11        12      cust_2             9/2/2025      $45   Completed
#
#    product_category
# 0       Electronics
# 1              Home
# 2       Electronics
# ...

# %%
data_frame.dtypes
# Out:
# order_id             int64
# customer_id         object
# order_date          object
# amount              object
# status              object
# product_category    object
# dtype: object

# %%
data_frame['order_date'] = pd.to_datetime(data_frame['order_date'],errors='coerce')

# %%
data_frame['order_date']
# Out:
# 0    2025-09-10
# 1    2025-08-22
# 2    2025-07-15
# 3    2025-08-01
# 4           NaT
# 5           NaT
# 6    2025-08-30
# 7    2025-09-12
# 8    2025-08-05
# 9    2025-06-20
# 10   2025-09-14
# 11   2025-09-02
# Name: order_date, dtype: datetime64[ns]

# %%
data_frame.dtypes
# Out:
# order_id                     int64
# customer_id                 object
# order_date          datetime64[ns]
# amount                      object
# status                      object
# product_category            object
# dtype: object

# %%
data_frame
# Out:
#     order_id customer_id order_date    amount     status product_category
# 0          1      cust_1 2025-09-10  $120.50   Completed      Electronics
# 1          2      cust_2 2025-08-22        80   complete             Home
# 2          3      cust_3 2025-07-15       200          C      Electronics
# 3          4      cust_1 2025-08-01       150  Completed      electronics
# 4          5      cust_4        NaT      $60    Returned         Clothing
# 5          6      cust_2        NaT        90  Completed             Home
# 6          7      cust_5 2025-08-30       250  Completed              NaN
# 7          8      cust_3 2025-09-12   $75.25   Completed      Electronics
# 8          9      cust_6 2025-08-05        30  completed             Food
# 9         10      cust_1 2025-06-20       400  Completed      Electronics
# 10        11      cust_7 2025-09-14        15  Completed            Books
# 11        12      cust_2 2025-09-02      $45   Completed             Home

# %%
data_frame['product_category'] = data_frame['product_category'].fillna('Unknown')

# %%
data_frame
# Out:
#     order_id customer_id order_date    amount     status product_category
# 0          1      cust_1 2025-09-10  $120.50   Completed      Electronics
# 1          2      cust_2 2025-08-22        80   complete             Home
# 2          3      cust_3 2025-07-15       200          C      Electronics
# 3          4      cust_1 2025-08-01       150  Completed      electronics
# 4          5      cust_4        NaT      $60    Returned         Clothing
# 5          6      cust_2        NaT        90  Completed             Home
# 6          7      cust_5 2025-08-30       250  Completed          Unknown
# 7          8      cust_3 2025-09-12   $75.25   Completed      Electronics
# 8          9      cust_6 2025-08-05        30  completed             Food
# 9         10      cust_1 2025-06-20       400  Completed      Electronics
# 10        11      cust_7 2025-09-14        15  Completed            Books
# 11        12      cust_2 2025-09-02      $45   Completed             Home

# %%
data_frame['amount'] = data_frame['amount'].replace('[$,]','',regex=True).astype(float)

# %%
data_frame
# Out:
#     order_id customer_id order_date  amount     status product_category
# 0          1      cust_1 2025-09-10  120.50  Completed      Electronics
# 1          2      cust_2 2025-08-22   80.00   complete             Home
# 2          3      cust_3 2025-07-15  200.00          C      Electronics
# 3          4      cust_1 2025-08-01  150.00  Completed      electronics
# 4          5      cust_4        NaT   60.00   Returned         Clothing
# 5          6      cust_2        NaT   90.00  Completed             Home
# 6          7      cust_5 2025-08-30  250.00  Completed          Unknown
# 7          8      cust_3 2025-09-12   75.25  Completed      Electronics
# 8          9      cust_6 2025-08-05   30.00  completed             Food
# 9         10      cust_1 2025-06-20  400.00  Completed      Electronics
# 10        11      cust_7 2025-09-14   15.00  Completed            Books
# 11        12      cust_2 2025-09-02   45.00  Completed             Home

# %%
data_frame['product_category'] = data_frame['product_category'].str.title()

# %%
data_frame
# Out:
#     order_id customer_id order_date  amount     status product_category
# 0          1      cust_1 2025-09-10  120.50  Completed      Electronics
# 1          2      cust_2 2025-08-22   80.00   complete             Home
# 2          3      cust_3 2025-07-15  200.00          C      Electronics
# 3          4      cust_1 2025-08-01  150.00  Completed      Electronics
# 4          5      cust_4        NaT   60.00   Returned         Clothing
# 5          6      cust_2        NaT   90.00  Completed             Home
# 6          7      cust_5 2025-08-30  250.00  Completed          Unknown
# 7          8      cust_3 2025-09-12   75.25  Completed      Electronics
# 8          9      cust_6 2025-08-05   30.00  completed             Food
# 9         10      cust_1 2025-06-20  400.00  Completed      Electronics
# 10        11      cust_7 2025-09-14   15.00  Completed            Books
# 11        12      cust_2 2025-09-02   45.00  Completed             Home

# %%
data_frame['status'] = data_frame['status'].replace({'C' : 'Completed', 'complete':'Completed','completed':'Completed'})

# %%
data_frame
# Out:
#     order_id customer_id order_date  amount     status product_category
# 0          1      cust_1 2025-09-10  120.50  Completed      Electronics
# 1          2      cust_2 2025-08-22   80.00  Completed             Home
# 2          3      cust_3 2025-07-15  200.00  Completed      Electronics
# 3          4      cust_1 2025-08-01  150.00  Completed      Electronics
# 4          5      cust_4        NaT   60.00   Returned         Clothing
# 5          6      cust_2        NaT   90.00  Completed             Home
# 6          7      cust_5 2025-08-30  250.00  Completed          Unknown
# 7          8      cust_3 2025-09-12   75.25  Completed      Electronics
# 8          9      cust_6 2025-08-05   30.00  Completed             Food
# 9         10      cust_1 2025-06-20  400.00  Completed      Electronics
# 10        11      cust_7 2025-09-14   15.00  Completed            Books
# 11        12      cust_2 2025-09-02   45.00  Completed             Home

# %%
data_frame.dtypes
# Out:
# order_id                     int64
# customer_id                 object
# order_date          datetime64[ns]
# amount                     float64
# status                      object
# product_category            object
# dtype: object
